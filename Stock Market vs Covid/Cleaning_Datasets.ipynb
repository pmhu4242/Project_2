# %%
#import dependencies
import pandas as pd
from datetime import datetime

# %%
#read file from american airlines csv
american_df = pd.read_csv("data/5yrAmericanAirlines.csv")

#display dataframe
american_df.head()
# Out:
#          Date  Close/Last     Volume     Open      High      Low
# 0  01/28/2021       $18.1  319607600   $20.33    $21.77   $16.82
# 1  01/27/2021      $16.56  178529000   $15.42    $17.81   $15.38
# 2  01/26/2021      $15.53   44571080   $15.52   $15.765   $15.33
# 3  01/25/2021      $15.43   61954500   $15.52    $15.56   $15.02
# 4  01/22/2021      $15.82   39126570   $15.57    $15.84   $15.46

# %%
#determining column names
american_df.columns
# Out:
# Index(['Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')

# %%
#renaming columns to differentiate between datasets
american_air = american_df.rename(columns={" Close/Last":"AAL_Close/Last"," Volume":"AAL_Volume"," Open":"AAL_Open"," High":"AAL_High"," Low":"AAL_Low"})

#display dataframe
american_air.head()
# Out:
#          Date AAL_Close/Last  AAL_Volume AAL_Open  AAL_High  AAL_Low
# 0  01/28/2021          $18.1   319607600   $20.33    $21.77   $16.82
# 1  01/27/2021         $16.56   178529000   $15.42    $17.81   $15.38
# 2  01/26/2021         $15.53    44571080   $15.52   $15.765   $15.33
# 3  01/25/2021         $15.43    61954500   $15.52    $15.56   $15.02
# 4  01/22/2021         $15.82    39126570   $15.57    $15.84   $15.46

# %%
#converting the date column from object to datetime, in order to better manipulate the data for graphs
american_air['Date'] = pd.to_datetime(american_air['Date'])
american_air
# Out:
#            Date AAL_Close/Last  AAL_Volume AAL_Open  AAL_High    AAL_Low
# 0    2021-01-28          $18.1   319607600   $20.33    $21.77     $16.82
# 1    2021-01-27         $16.56   178529000   $15.42    $17.81     $15.38
# 2    2021-01-26         $15.53    44571080   $15.52   $15.765     $15.33
# 3    2021-01-25         $15.43    61954500   $15.52    $15.56     $15.02
# 4    2021-01-22         $15.82    39126570   $15.57    $15.84     $15.46
# ...         ...            ...         ...      ...       ...        ...
# 1254 2016-02-04         $38.21     8599427   $37.34     $38.6    $36.701
# 1255 2016-02-03         $37.51    12390940   $37.38    $37.61    $35.755
# 1256 2016-02-02         $37.03    12396210   $38.83    $38.97        $37
# 1257 2016-02-01         $39.38    12022830      $39    $39.94     $38.63
# 1258 2016-01-29         $38.99    20957430   $37.52   $39.085   $36.5982
#
# [1259 rows x 6 columns]

# %%
#pulling out the day, month, and year from the date column into their own seperate columns
american_air['year'] = american_air['Date'].dt.year
american_air['month'] = american_air['Date'].dt.month
american_air['day'] = american_air['Date'].dt.day

# %%
#display dataframe
american_air.head()
# Out:
#         Date AAL_Close/Last  AAL_Volume AAL_Open  AAL_High  AAL_Low  year  \
# 0 2021-01-28          $18.1   319607600   $20.33    $21.77   $16.82  2021
# 1 2021-01-27         $16.56   178529000   $15.42    $17.81   $15.38  2021
# 2 2021-01-26         $15.53    44571080   $15.52   $15.765   $15.33  2021
# 3 2021-01-25         $15.43    61954500   $15.52    $15.56   $15.02  2021
# 4 2021-01-22         $15.82    39126570   $15.57    $15.84   $15.46  2021
#
#    month  day
# 0      1   28
# 1      1   27
# 2      1   26
# 3      1   25
# 4      1   22

# %%
#read file from jetblue airlines csv
jetblue = pd.read_csv("data/5yrJetBlue.csv")

#display dataframe
jetblue.head()
# Out:
#          Date  Close/Last    Volume     Open       High      Low
# 0  01/28/2021      $14.65  14905990   $15.15      $15.7   $14.58
# 1  01/27/2021      $14.68  10653670   $14.53   $15.0981   $14.52
# 2  01/26/2021      $14.85   7328490   $14.69     $14.97   $14.66
# 3  01/25/2021      $14.59   8927983    $15.1     $15.18   $14.57
# 4  01/22/2021      $15.29   4820559   $15.07      $15.3   $15.02

# %%
#read file from southwest airlines csv
southwest = pd.read_csv("data/5yrSouthwest.csv")

#display dataframe
southwest.head()
# Out:
#          Date  Close/Last    Volume     Open     High      Low
# 0  01/28/2021       $44.6  12404570   $45.16   $46.25   $44.33
# 1  01/27/2021      $44.15  10428720   $45.25    $45.7   $43.87
# 2  01/26/2021      $45.81   5667206   $45.75   $46.22    $45.6
# 3  01/25/2021      $45.62  13345650   $47.28   $47.34   $45.17
# 4  01/22/2021      $47.39   4812538   $47.18   $47.75   $47.07

# %%
#read file from spirit airlines csv
spirit = pd.read_csv("data/5yrSpiritAirlines.csv")

#display dataframe
spirit.head()
# Out:
#          Date  Close/Last   Volume     Open     High        Low
# 0  01/28/2021      $26.71  7819099   $26.76   $27.45     $26.06
# 1  01/27/2021      $25.45  7976574   $26.28   $27.02   $25.2001
# 2  01/26/2021      $26.86  3390666   $27.41   $27.96     $26.79
# 3  01/25/2021      $27.26  5208525   $27.34   $27.89     $26.07
# 4  01/22/2021      $27.67  3078762    $26.8   $27.69     $26.66

# %%
#read file from united airlines csv
united_air = pd.read_csv("data/5yrUnitedAirlines.csv")

#display dataframe
united_air.head()
# Out:
#          Date  Close/Last    Volume      Open     High       Low
# 0  01/28/2021      $42.55  22174960   $42.827    $44.2    $41.62
# 1  01/27/2021      $40.91  15279990    $40.74   $41.65   $40.312
# 2  01/26/2021      $41.25  13388600     $40.8   $41.39    $40.56
# 3  01/25/2021      $40.38  20281920    $41.54   $41.73     $39.9
# 4  01/22/2021      $42.14  13544970    $41.95   $42.29    $41.61

# %%
#read file from delta airlines csv
delta_air = pd.read_csv("data/5yrDeltaAirlines.csv")

#display dataframe
delta_air.head()
# Out:
#          Date  Close/Last    Volume     Open       High        Low
# 0  01/29/2021      $37.96  17989710   $39.27     $39.83     $37.74
# 1  01/28/2021      $40.08  21654010   $39.55     $40.37     $38.99
# 2  01/27/2021      $38.52  16953390   $38.63   $39.2254   $38.1609
# 3  01/26/2021      $39.32  10599370   $39.26     $39.64     $38.98
# 4  01/25/2021       $38.9  15964900   $39.63     $39.75     $38.42

# %%
delta_air.columns
# Out:
# Index(['Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')
